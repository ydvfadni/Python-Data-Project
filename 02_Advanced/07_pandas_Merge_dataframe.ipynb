# %%
## importing libraries 
import pandas as pd 
from datasets import load_dataset
import matplotlib.pyplot as plt 

## loading data 
dataset= load_dataset('lukebarousse/data_jobs')
df= dataset['train'].to_pandas()

## data cleaning 
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df_tech_jobs=pd.read_csv("https://lukeb.co/software_csv",index_col='job_posted_month')

# %%
df_tech_jobs
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
## now we get the data like we used in last class that job posting in india in data field over the year 
df_india=df[df['job_country']=='India'].copy()
df_india['job_posted_month']=df_india['job_posted_date'].dt.strftime('%B')
df_india=df_india.pivot_table(index='job_posted_month',columns='job_title_short',aggfunc='size')
df_india.reset_index(inplace=True)
df_india['month_no']=pd.to_datetime(df_india['job_posted_month'],format='%B').dt.month
df_india.sort_values('month_no',inplace=True)
df_india.set_index('job_posted_month',inplace=True)
df_india.drop(columns='month_no',inplace=True)
df_india
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        175              31           628
# February                       143              35           433
# March                          116              37           422
# April                          170              32           418
# May                            103              14           278
# June                           146              26           367
# July                           142              25           457
# August                         189              25           618
# September                      155              34           630
# October                        170              36           500
# November                       192              29           722
# December                       186              27           648
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
## merge two data frame 
df_india_merged=df_india.merge(df_tech_jobs,on='job_posted_month')

# %%
## 
top_5=(df_india_merged
       .sum()
       .sort_values(ascending=False)
       .head(5)
       .index # get the index of top 5 
       .to_list()
)

top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'UI/UX Designer',
#  'Data Engineer']

# %%
df_india_merged[top_5].plot(kind='line')
plt.title('Monthly job posting for top tech jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.ylim(0,25000)
plt.legend()
plt.show()
